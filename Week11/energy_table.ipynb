# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem

from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole

rdkit.__version__
# Out:
# '2022.09.1'

# %%
import pandas as pd
from rdkit.Chem import PandasTools

# %%
#First, let's print the molecules from the csv file we made

data = pd.read_csv('smiles.csv')
data
# Out:
#            smiles
# 0             C=C
# 1             C=O
# 2             C#N
# 3             CCO
# 4        CCC(=O)O
# 5          CN=C=O
# 6      C1=CCC=CC1
# 7     C1=CC=CC=C1
# 8  C1=C(C)C=CC=C1
# 9  C1CCC2CCCCC2C1

# %%
PandasTools.AddMoleculeColumnToFrame(data, smilesCol='smiles')
data.head(1)
# Out:
#   smiles                                             ROMol
# 0    C=C  <rdkit.Chem.rdchem.Mol object at 0x14f8d1b09a50>

# %%
#Next, we can draw out our molecules as follows:

PandasTools.FrameToGridImage(data.head(10),  legendsCol='smiles', molsPerRow=5)

# %%
data["n_Atoms"] = data['ROMol'].map(lambda x: x.GetNumAtoms())
data.head(1)
# Out:
#   smiles                                             ROMol  n_Atoms
# 0    C=C  <rdkit.Chem.rdchem.Mol object at 0x14f8d1b09a50>        2

# %%
data = data.drop(['ROMol'], axis=1)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 3
#       1 #Now, we can add the number of atoms to our energy table as follows
# ----> 3 data = data.drop(['ROMol'], axis=1)
#       4 data
#
# File /ext3/miniconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /ext3/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...
