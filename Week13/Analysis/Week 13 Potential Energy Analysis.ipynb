# %% [markdown]
# ### This Jupyter Notebook will analyze the energy of various systems and monitor a reaction coordinate

# %%
import numpy as np
import matplotlib.pyplot as mplt
import seaborn as sns
import pandas as pd

# %%
#First, we will link to our NVT

data_nvt = np.loadtxt('/home/hv454/comp-lab-class-2023/Week13/Outputs/NVT-1.ener')

nvt_data = pd.DataFrame(data_nvt, columns=['Step Nr.', 'Time[fs]', 'Kin.[a.u.]', 'Temp[K]', 'Pot.[a.u.]', 'Cons Qty[a.u.]', 'UsedTime[s]'])

# %%
#First, we will present the NVT data as a table below 

nvt_data
# Out:
#        Step Nr.  Time[fs]  Kin.[a.u.]     Temp[K]  Pot.[a.u.]  Cons Qty[a.u.]  \
# 0           0.0       0.0   71.038787  298.000000 -341.304174     -270.265387
# 1           1.0       0.5   67.808256  284.448272 -337.713187     -270.064937
# 2           2.0       1.0   60.713738  254.687538 -329.900930     -269.669622
# 3           3.0       1.5   55.406526  232.424362 -323.723054     -269.469951
# 4           4.0       2.0   54.454305  228.429898 -322.195686     -269.622588
# ...         ...       ...         ...         ...         ...             ...
# 9996     9996.0    4998.0   71.329935  299.221332 -259.676576     -269.541126
# 9997     9997.0    4998.5   71.266297  298.954381 -259.608007     -269.535678
# 9998     9998.0    4999.0   71.105412  298.279483 -259.470525     -269.527327
# 9999     9999.0    4999.5   70.945576  297.608991 -259.390264     -269.526101
# 10000   10000.0    5000.0   71.017893  297.912353 -259.385960     -269.533045
#
#        UsedTime[s]
# ...

# %%
#Now, we will create our plot of Potential Energy vs. Time

time = nvt_data['Time[fs]']
potential = nvt_data['Pot.[a.u.]']

mplt.figure(figsize=(20,15))
mplt.plot(time, potential)
mplt.title('Potential Energy vs. Time')
mplt.xlabel('Time')
mplt.ylabel('Potential Energy [a.u.]')
mplt.grid(True)

mplt.show()

# %%
#Next, we will do the same thing but now with our NPT data

data_npt = np.loadtxt('/home/hv454/comp-lab-class-2023/Week13/Outputs/NPT-1.ener')

npt_data = pd.DataFrame(data_npt, columns=['Step Nr.', 'Time[fs]', 'Kin.[a.u.]', 'Temp[K]', 'Pot.[a.u.]', 'Cons Qty[a.u.]', 'UsedTime[s]'])

# %%
npt_data
# Out:
#        Step Nr.  Time[fs]  Kin.[a.u.]     Temp[K]  Pot.[a.u.]  Cons Qty[a.u.]  \
# 0           0.0       0.0   71.017893  297.912353 -259.385960     -269.518620
# 1           1.0       0.5   70.889400  297.373337 -259.354010     -269.524747
# 2           2.0       1.0   70.546706  295.935774 -259.217127     -269.522176
# 3           3.0       1.5   70.529239  295.862502 -259.024260     -269.513169
# 4           4.0       2.0   70.413938  295.378827 -258.906199     -269.506991
# ...         ...       ...         ...         ...         ...             ...
# 49996   49996.0   24998.0   71.370708  299.392371 -265.354888     -269.453425
# 49997   49997.0   24998.5   71.370441  299.391253 -265.409527     -269.455785
# 49998   49998.0   24999.0   71.375137  299.410949 -265.451738     -269.456801
# 49999   49999.0   24999.5   71.543129  300.115658 -265.468389     -269.455838
# 50000   50000.0   25000.0   71.590273  300.313424 -265.467049     -269.454172
#
#        UsedTime[s]
# ...

# %%
#Now, we will create our plot of Potential Energy vs. Time

time = npt_data['Time[fs]']
potential = npt_data['Pot.[a.u.]']

mplt.figure(figsize=(20,15))
mplt.plot(time, potential)
mplt.title('Potential Energy vs. Time')
mplt.xlabel('Time')
mplt.ylabel('Potential Energy [a.u.]')
mplt.grid(True)

mplt.show()

# %%
#Next, we will do the same thing but for the QM/MM run

data_QM = np.loadtxt('/home/hv454/comp-lab-class-2023/Week13/Outputs/monitor/MONITOR-1.ener')
QM_data = pd.DataFrame(data_QM, columns=['Step Nr.', 'Time[fs]', 'Kin.[a.u.]', 'Temp[K]', 'Pot.[a.u.]', 'Cons Qty[a.u.]', 'UsedTime[s]'])

# %%
QM_data
# Out:
#        Step Nr.  Time[fs]  Kin.[a.u.]     Temp[K]  Pot.[a.u.]  Cons Qty[a.u.]  \
# 0           0.0       0.0   71.590273  300.313424 -387.485380     -315.894635
# 1           1.0       0.5   71.661531  300.612342 -387.560885     -315.897022
# 2           2.0       1.0   71.821417  301.283046 -387.729683     -315.904039
# 3           3.0       1.5   71.964089  301.881543 -387.879568     -315.909312
# 4           4.0       2.0   72.007900  302.065323 -387.924410     -315.908356
# ...         ...       ...         ...         ...         ...             ...
# 9996     9996.0    4998.0   70.868305  297.284847 -386.621851     -315.891932
# 9997     9997.0    4998.5   70.917689  297.492005 -386.675533     -315.895763
# 9998     9998.0    4999.0   70.989183  297.791915 -386.753025     -315.901297
# 9999     9999.0    4999.5   71.007312  297.867965 -386.772015     -315.901695
# 10000   10000.0    5000.0   70.963298  297.683330 -386.723605     -315.896837
#
#        UsedTime[s]
# ...

# %%
#Now, we will create our plot of Potential Energy vs. Time from the QM data

time = QM_data['Time[fs]']
potential = QM_data['Pot.[a.u.]']

mplt.figure(figsize=(20,15))
mplt.plot(time, potential)
mplt.title('Potential Energy vs. Time')
mplt.xlabel('Time')
mplt.ylabel('Potential Energy [a.u.]')
mplt.grid(True)

mplt.show()

# %%
#Next, we will do the same for the other 2 ener files 

data_QM_1=np.loadtxt('/home/hv454/comp-lab-class-2023/Week13/Outputs/metad1_initmonitor/METADYN-1.ener')
QM_1_data =pd.DataFrame(data_QM_1, columns=['Step Nr.', 'Time[fs]', 'Kin.[a.u.]', 'Temp[K]', 'Pot.[a.u.]', 'Cons Qty[a.u.]', 'UsedTime[s]'])

# %%
QM_1_data
# Out:
#        Step Nr.  Time[fs]  Kin.[a.u.]     Temp[K]  Pot.[a.u.]  Cons Qty[a.u.]  \
# 0           0.0       0.0   70.963298  297.683330 -386.723605     -315.759835
# 1           1.0       0.5   70.922892  297.513833 -386.680243     -315.755053
# 2           2.0       1.0   70.954527  297.646537 -386.714277     -315.755632
# 3           3.0       1.5   71.051548  298.053530 -386.818293     -315.760807
# 4           4.0       2.0   71.143977  298.441260 -386.916408     -315.764672
# ...         ...       ...         ...         ...         ...             ...
# 59996   59996.0   29998.0   70.986542  297.780836 -387.415391     -314.348742
# 59997   59997.0   29998.5   70.967239  297.699862 -387.397745     -314.349490
# 59998   59998.0   29999.0   70.899509  297.415744 -387.327496     -314.346072
# 59999   59999.0   29999.5   70.831181  297.129115 -387.255968     -314.341984
# 60000   60000.0   30000.0   70.818904  297.077613 -387.241938     -314.339360
#
#        UsedTime[s]
# ...

# %%
time = QM_1_data['Time[fs]']
potential = QM_1_data['Pot.[a.u.]']

mplt.figure(figsize=(20,15))
mplt.plot(time, potential)
mplt.title('Potential Energy vs. Time')
mplt.xlabel('Time')
mplt.ylabel('Potential Energy [a.u.]')
mplt.grid(True)

mplt.show()

# %%
data_QM_2=np.loadtxt('/home/hv454/comp-lab-class-2023/Week13/Outputs/metad1_initmonitor_freqhills/METADYN-1.ener')
QM_2_data =pd.DataFrame(data_QM_2, columns=['Step Nr.', 'Time[fs]', 'Kin.[a.u.]', 'Temp[K]', 'Pot.[a.u.]', 'Cons Qty[a.u.]', 'UsedTime[s]'])

# %%
QM_2_data
# Out:
#        Step Nr.  Time[fs]  Kin.[a.u.]      Temp[K]  Pot.[a.u.]  \
# 0           0.0       0.0   70.963298   297.683330 -386.723605
# 1           1.0       0.5   70.922892   297.513833 -386.680243
# 2           2.0       1.0   70.954527   297.646537 -386.714277
# 3           3.0       1.5   71.051548   298.053530 -386.818293
# 4           4.0       2.0   71.143977   298.441260 -386.916408
# ...         ...       ...         ...          ...         ...
# 27350   27350.0   13675.0  181.236220   760.266267 -232.757233
# 27351   27351.0   13675.5  263.369818  1104.807795 -317.823062
# 27352   27352.0   13676.0  317.406722  1331.486740 -373.739430
# 27353   27353.0   13676.5  325.303927  1364.614656 -380.567380
# 27354   27354.0   13677.0  284.867854  1194.989723 -339.536218
#
#        Cons Qty[a.u.]  UsedTime[s]
# 0         -315.759835     0.000000
# 1         -315.755053     3.145175
# 2         -315.755632     0.717505
# 3         -315.760807     0.692836
# ...

# %%
time = QM_2_data['Time[fs]']
potential = QM_2_data['Pot.[a.u.]']

mplt.figure(figsize=(20,15))
mplt.plot(time, potential)
mplt.title('Potential Energy vs. Time')
mplt.xlabel('Time')
mplt.ylabel('Potential Energy [a.u.]')
mplt.grid(True)

mplt.show()
